# %% [markdown]
# # Diplomatura en IA - UP
# ### Practico N°2 - Jun26
# ### Alumno: Gonzalez Marta Elizabeth
# ### Notebook 01  - Lectura y descubrimientos -

# %% [markdown]
# ### Lirerias

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
print("Librerías cargadas")
# Out:
# Librerías cargadas

# %%
# Visualizar en que repositorio estas posicionado:

import os
os.getcwd()
# Out:
# 'C:\\Users\\Usuario\\DiploIA\\Practica\\Practico2\\notebooks'

# %%
# Lista de archivos en del repositorio:

import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  '01_lectura_y_discovery.ipynb',
#  '02_eda.ipynb',
#  '03_preprocesamiento.ipynb',
#  '04_entrenamiento_y_optimizacion.ipynb',
#  '05_validacion.ipynb',
#  '06_prediccion.ipynb',
#  'best_model.pkl',
#  'Untitled2.ipynb']

# %% [markdown]
# #### Variables y Carga del Dataset

# %%
# Ubicacion del dataset excel:

PATH = "../data/raw/smoking_prediction.xlsx"

# %%
# Lectura del archivo:

df = pd.read_excel(PATH)

# %% [markdown]
# #### Lectura de Datos

# %%
# Dimensiones

print(f"Cantidad de filas: {df.shape[0]}")
print(f"Cantidad de columnas: {df.shape[1]}")
# Out:
# Cantidad de filas: 50000
# Cantidad de columnas: 27

# %%
# Primeras observaciones:

df.head()
# Out:
#    ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 0   0      F   40         155          60   3.377083        0.043056
# 1   1      F   40         160          60   3.375000        0.005556
# 2   2      M   55         170          60   3.333333        0.005556
# 3   3      M   40         165          70   3.666667        0.045139
# 4   4      F   40         155          60   3.583333        0.041667
#
#    eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 0         0.041667       0.041667        0.041667  ...    0.506250
# 1         0.004167       0.041667        0.041667  ...    0.504861
# 2         0.005556       0.041667        0.041667  ...    0.630556
# 3         0.045139       0.041667        0.041667  ...    0.588194
# 4         0.041667       0.041667        0.041667  ...    0.503472
#
#    Urine protein  serum creatinine       AST       ALT       Gtp  oral  \
# 0       0.041667          0.004861  0.750000  0.791667  1.125000     Y
# ...

# %%
# Ultimas observaciones:
df.tail()
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 49995  27343      M   50         160          55   2.961806        0.004861
# 49996  27350      M   30         170          70   3.333333        0.045139
# 49997  27351      M   20         165          65   3.541667        0.045139
# 49998  27352      F   60         160          45   2.961806        0.002778
# 49999  27354      M   45         170          80   4.000000        0.045139
#
#        eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# 49995         0.005556       0.041667        0.041667  ...    0.547917
# 49996         0.041667       0.041667        0.041667  ...    0.629167
# 49997         0.045139       0.041667        0.041667  ...    0.670833
# 49998         0.002778       0.041667        0.041667  ...    0.584028
# 49999         0.041667       0.041667        0.041667  ...    0.625000
#
#        Urine protein  serum creatinine       AST       ALT       Gtp  oral  \
# ...

# %%
# Muestra aleatoria:

df.sample(n=10, random_state=42)
# Out:
#           ID gender  age  height(cm)  weight(kg)  waist(cm)  eyesight(left)  \
# 33553  41917      M   55         175          75   3.750000        0.041667
# 9427   11817      F   40         160          55   2.797222        0.006250
# 199      260      F   40         150          65   3.836806        0.005556
# 12447  15517      F   50         155          65   3.708333        0.043056
# 39489  49334      F   45         150          50   2.750000        0.041667
# 42724  53412      F   55         150          65   3.208333        0.005556
# 10822  13539      M   40         170          65   3.083333        0.041667
# 49498  24826      F   65         150          50   3.166667        0.005556
# 4144    5206      M   40         180          85   4.041667        0.045139
# 36958  46188      M   45         175          80   3.711806        0.006250
#
#        eyesight(right)  hearing(left)  hearing(right)  ...  hemoglobin  \
# ...

# %%
# Estructura:

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   50000 non-null  int64
#  1   gender               50000 non-null  object
#  2   age                  50000 non-null  int64
#  3   height(cm)           50000 non-null  int64
#  4   weight(kg)           50000 non-null  int64
#  5   waist(cm)            50000 non-null  float64
#  6   eyesight(left)       50000 non-null  float64
#  7   eyesight(right)      50000 non-null  float64
#  8   hearing(left)        50000 non-null  float64
#  9   hearing(right)       50000 non-null  float64
#  10  systolic             50000 non-null  float64
#  11  relaxation           50000 non-null  float64
#  12  fasting blood sugar  50000 non-null  float64
#  13  Cholesterol          50000 non-null  float64
#  14  triglyceride         50000 non-null  float64
# ...

# %%
# Diccionario de Variables

df.columns
# Out:
# Index(['ID', 'gender', 'age', 'height(cm)', 'weight(kg)', 'waist(cm)',
#        'eyesight(left)', 'eyesight(right)', 'hearing(left)', 'hearing(right)',
#        'systolic', 'relaxation', 'fasting blood sugar', 'Cholesterol',
#        'triglyceride', 'HDL', 'LDL', 'hemoglobin', 'Urine protein',
#        'serum creatinine', 'AST', 'ALT', 'Gtp', 'oral', 'dental caries',
#        'tartar', 'smoking'],
#       dtype='object')

# %%
# Estadistica Descritptiva:

df.describe().T
# Out:
#                        count          mean           std         min  \
# ID                   50000.0  26284.994580  16015.070567    0.000000
# age                  50000.0     44.189300     12.090086   20.000000
# height(cm)           50000.0    164.652000      9.208778  130.000000
# weight(kg)           50000.0     65.878700     12.831355   30.000000
# waist(cm)            50000.0      3.414852      0.386765    2.125000
# eyesight(left)       50000.0      0.028446      0.024007    0.000694
# eyesight(right)      50000.0      0.028304      0.024216    0.000694
# hearing(left)        50000.0      0.042736      0.006588    0.041667
# hearing(right)       50000.0      0.042758      0.006655    0.041667
# systolic             50000.0      5.062531      0.570100    2.958333
# relaxation           50000.0      3.167326      0.403490    1.666667
# fasting blood sugar  50000.0      4.137704      0.865933    1.916667
# Cholesterol          50000.0      8.205148      1.514168    2.291667
# ...

# %%
# Analisis de Valores Nulos

nulos = pd.DataFrame({
    'Cantidad': df.isnull().sum(),
    'Porcentaje': (df.isnull().sum()/len(df))*100
})

nulos.sort_values('Porcentaje', ascending=False)
# Out:
#                      Cantidad  Porcentaje
# ID                          0         0.0
# triglyceride                0         0.0
# tartar                      0         0.0
# dental caries               0         0.0
# oral                        0         0.0
# Gtp                         0         0.0
# ALT                         0         0.0
# AST                         0         0.0
# serum creatinine            0         0.0
# Urine protein               0         0.0
# hemoglobin                  0         0.0
# LDL                         0         0.0
# HDL                         0         0.0
# Cholesterol                 0         0.0
# gender                      0         0.0
# fasting blood sugar         0         0.0
# relaxation                  0         0.0
# systolic                    0         0.0
# hearing(right)              0         0.0
# hearing(left)               0         0.0
# eyesight(right)             0         0.0
# ...

# %%
# Valores faltantes:

df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
# Registros Duplicados:

duplicados = df.duplicated().sum()

print("Duplicados:", duplicados)
# Out:
# Duplicados: 0

# %%
# Variables Categoricas:

categoricas = df.select_dtypes(include=['object'])

categoricas.columns
# Out:
# Index(['gender', 'oral', 'tartar'], dtype='object')

# %%
# Variable Objetivo - Distribucion:

df['smoking'].value_counts()
# Out:
# smoking
# 0    31671
# 1    18329
# Name: count, dtype: int64

# %%
# Variable Objetivo - Porcentaje:

round(
    df['smoking'].value_counts(normalize=True)*100,
    2
)
# Out:
# smoking
# 0    63.34
# 1    36.66
# Name: proportion, dtype: float64

# %%
# Exportación para la Notebook 02

df.to_csv(
    "../data/processed/01_dataset_analizado.csv",
    index=False
)

print("Archivo exportado correctamente")
# Out:
# Archivo exportado correctamente
